# %%
import requests
import re

idx = 12345
base_url = "http://www.pythonchallenge.com/pc/def/linkedlist.php?nothing="

for i in range(400):
    response = requests.get(base_url + str(idx))
    contents = response.content.decode('utf-8')
    print("Contents:", contents)
    res = re.search('and the next nothing is ', contents)
    if res:
        res = res.start()
        idx = contents[res +24:res+29]
    else:
        # Check if the contents indicate to divide by 2
        if "Divide by two" in contents:
            idx = int(idx) // 2
            continue
        print("Stopping")
        break
# Out:
# Contents: and the next nothing is 44827
# Contents: and the next nothing is 45439
# Contents: <font color=red>Your hands are getting tired </font>and the next nothing is 94485
# Contents: and the next nothing is 72198
# Contents: and the next nothing is 80992
# Contents: and the next nothing is 8880
# Contents: and the next nothing is 40961
# Contents: and the next nothing is 58765
# Contents: and the next nothing is 46561
# Contents: and the next nothing is 13418
# Contents: and the next nothing is 41954
# Contents: and the next nothing is 46782
# Contents: and the next nothing is 92730
# Contents: and the next nothing is 89229
# Contents: and the next nothing is 25646
# Contents: and the next nothing is 74288
# Contents: and the next nothing is 25945
# Contents: and the next nothing is 39876
# Contents: and the next nothing is 8498
# Contents: and the next nothing is 34684
# Contents: and the next nothing is 62316
# Contents: and the next nothing is 71331
# Contents: and the next nothing is 59717
# Contents: and the next nothing is 76893
# Contents: and the next nothing is 44091
# Contents: and the next nothing is 73241
# Contents: and the next nothing is 19242
# Contents: and the next nothing is 17476
# Contents: and the next nothing is 39566
# Contents: and the next nothing is 81293
# Contents: and the next nothing is 25857
# Contents: and the next nothing is 74343
# Contents: and the next nothing is 39410
# Contents: and the next nothing is 5505
# Contents: and the next nothing is 27104
# Contents: and the next nothing is 54003
# Contents: and the next nothing is 23501
# Contents: and the next nothing is 21110
# Contents: and the next nothing is 88399
# Contents: and the next nothing is 49740
# Contents: and the next nothing is 31552
# Contents: and the next nothing is 39998
# Contents: and the next nothing is 19755
# Contents: and the next nothing is 64624
# Contents: and the next nothing is 37817
# Contents: and the next nothing is 43427
# Contents: and the next nothing is 15115
# Contents: and the next nothing is 44327
# Contents: and the next nothing is 7715
# Contents: and the next nothing is 15248
# Contents: and the next nothing is 61895
# Contents: and the next nothing is 54759
# Contents: and the next nothing is 54270
# Contents: and the next nothing is 51332
# Contents: and the next nothing is 63481
# Contents: and the next nothing is 12362
# Contents: and the next nothing is 94476
# Contents: and the next nothing is 87810
# Contents: and the next nothing is 6027
# Contents: and the next nothing is 47551
# Contents: and the next nothing is 79498
# Contents: and the next nothing is 81226
# Contents: and the next nothing is 4256
# Contents: and the next nothing is 62734
# Contents: and the next nothing is 25666
# Contents: and the next nothing is 14781
# Contents: and the next nothing is 21412
# Contents: and the next nothing is 55205
# Contents: and the next nothing is 65516
# Contents: and the next nothing is 53535
# Contents: and the next nothing is 4437
# Contents: and the next nothing is 43442
# Contents: and the next nothing is 91308
# Contents: and the next nothing is 1312
# Contents: and the next nothing is 36268
# Contents: and the next nothing is 34289
# Contents: and the next nothing is 46384
# Contents: and the next nothing is 18097
# Contents: and the next nothing is 9401
# Contents: and the next nothing is 54249
# Contents: and the next nothing is 29247
# Contents: and the next nothing is 13115
# Contents: and the next nothing is 23053
# Contents: and the next nothing is 3875
# Contents: and the next nothing is 16044
# Contents: Yes. Divide by two and keep going.
# Contents: and the next nothing is 25357
# Contents: and the next nothing is 89879
# Contents: and the next nothing is 80119
# Contents: and the next nothing is 50290
# Contents: and the next nothing is 9297
# Contents: and the next nothing is 30571
# Contents: and the next nothing is 7414
# Contents: and the next nothing is 30978
# Contents: and the next nothing is 16408
# Contents: and the next nothing is 80109
# Contents: and the next nothing is 55736
# Contents: and the next nothing is 15357
# Contents: and the next nothing is 80887
# Contents: and the next nothing is 35014
# Contents: and the next nothing is 16523
# Contents: and the next nothing is 50286
# Contents: and the next nothing is 34813
# Contents: and the next nothing is 77562
# Contents: and the next nothing is 54746
# Contents: and the next nothing is 22680
# Contents: and the next nothing is 19705
# Contents: and the next nothing is 77000
# Contents: and the next nothing is 27634
# Contents: and the next nothing is 21008
# Contents: and the next nothing is 64994
# Contents: and the next nothing is 66109
# Contents: and the next nothing is 37855
# Contents: and the next nothing is 36383
# Contents: and the next nothing is 68548
# Contents: and the next nothing is 96070
# Contents: and the next nothing is 83051
# Contents: and the next nothing is 58026
# Contents: and the next nothing is 44726
# Contents: and the next nothing is 35748
# Contents: and the next nothing is 61287
# Contents: and the next nothing is 559
# Contents: and the next nothing is 81318
# Contents: and the next nothing is 50443
# Contents: and the next nothing is 1570
# Contents: and the next nothing is 75244
# Contents: and the next nothing is 56265
# Contents: and the next nothing is 17694
# Contents: and the next nothing is 48033
# Contents: and the next nothing is 56523
# Contents: and the next nothing is 51253
# Contents: and the next nothing is 85750
# Contents: and the next nothing is 42760
# Contents: and the next nothing is 11877
# Contents: and the next nothing is 15962
# Contents: and the next nothing is 75494
# Contents: and the next nothing is 87283
# Contents: and the next nothing is 40396
# Contents: and the next nothing is 49574
# Contents: and the next nothing is 82682
# Contents: There maybe misleading numbers in the
# text. One example is 82683. Look only for the next nothing and the next nothing is 63579
# Contents: and the next nothing is 37278
# Contents: and the next nothing is 53548
# Contents: and the next nothing is 66081
# Contents: and the next nothing is 67753
# Contents: and the next nothing is 56337
# Contents: and the next nothing is 3356
# Contents: and the next nothing is 94525
# Contents: and the next nothing is 89574
# Contents: and the next nothing is 4413
# Contents: and the next nothing is 82294
# Contents: and the next nothing is 56060
# Contents: and the next nothing is 95493
# Contents: and the next nothing is 80865
# Contents: and the next nothing is 66242
# Contents: and the next nothing is 16065
# Contents: and the next nothing is 62145
# Contents: and the next nothing is 23147
# Contents: and the next nothing is 83763
# Contents: and the next nothing is 62381
# Contents: and the next nothing is 76841
# Contents: and the next nothing is 91706
# Contents: and the next nothing is 9268
# Contents: and the next nothing is 64814
# Contents: and the next nothing is 80809
# Contents: and the next nothing is 14039
# Contents: and the next nothing is 73355
# Contents: and the next nothing is 81905
# Contents: and the next nothing is 36402
# Contents: and the next nothing is 27221
# Contents: and the next nothing is 79607
# Contents: and the next nothing is 91763
# Contents: and the next nothing is 11631
# Contents: and the next nothing is 76396
# Contents: and the next nothing is 69905
# Contents: and the next nothing is 11073
# Contents: and the next nothing is 71281
# Contents: and the next nothing is 54345
# Contents: and the next nothing is 19047
# Contents: and the next nothing is 34376
# Contents: and the next nothing is 3193
# Contents: and the next nothing is 74258
# Contents: and the next nothing is 62712
# Contents: and the next nothing is 1823
# Contents: and the next nothing is 21232
# Contents: and the next nothing is 87890
# Contents: and the next nothing is 21545
# Contents: and the next nothing is 37136
# Contents: and the next nothing is 23060
# Contents: and the next nothing is 5385
# Contents: and the next nothing is 4620
# Contents: and the next nothing is 39111
# Contents: and the next nothing is 35914
# Contents: and the next nothing is 60310
# Contents: and the next nothing is 19178
# Contents: and the next nothing is 44671
# Contents: and the next nothing is 45736
# Contents: and the next nothing is 9216
# Contents: and the next nothing is 12585
# Contents: and the next nothing is 11302
# Contents: and the next nothing is 33096
# Contents: and the next nothing is 13967
# Contents: and the next nothing is 57004
# Contents: and the next nothing is 64196
# Contents: and the next nothing is 73929
# Contents: and the next nothing is 24800
# Contents: and the next nothing is 25081
# Contents: and the next nothing is 90033
# Contents: and the next nothing is 45919
# Contents: and the next nothing is 54827
# Contents: and the next nothing is 73950
# Contents: and the next nothing is 56978
# Contents: and the next nothing is 8133
# Contents: and the next nothing is 61900
# Contents: and the next nothing is 47769
# Contents: and the next nothing is 631
# Contents: and the next nothing is 2284
# Contents: and the next nothing is 60074
# Contents: and the next nothing is 35959
# Contents: and the next nothing is 57158
# Contents: and the next nothing is 90990
# Contents: and the next nothing is 27935
# Contents: and the next nothing is 99927
# Contents: and the next nothing is 41785
# Contents: and the next nothing is 32660
# Contents: and the next nothing is 4328
# Contents: and the next nothing is 42067
# Contents: and the next nothing is 8743
# Contents: and the next nothing is 38613
# Contents: and the next nothing is 21100
# Contents: and the next nothing is 77864
# Contents: and the next nothing is 6523
# Contents: and the next nothing is 6927
# Contents: and the next nothing is 82930
# Contents: and the next nothing is 35846
# Contents: and the next nothing is 31785
# Contents: and the next nothing is 41846
# Contents: and the next nothing is 72387
# Contents: and the next nothing is 59334
# Contents: and the next nothing is 65520
# Contents: and the next nothing is 93781
# Contents: and the next nothing is 55840
# Contents: and the next nothing is 80842
# Contents: and the next nothing is 59022
# Contents: and the next nothing is 23298
# Contents: and the next nothing is 27709
# Contents: and the next nothing is 96791
# Contents: and the next nothing is 75635
# Contents: and the next nothing is 52899
# Contents: and the next nothing is 66831
# Contents: peak.html
# Stopping
